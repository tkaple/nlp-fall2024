# %% [markdown]
# #### 1. Importing Libraries

# %%
from pymongo.mongo_client import MongoClient
uri = "mongodb+srv://aniruddha:HFH0ZHWPs0QgbJqZ@wikiclusterbusinesspers.g6alv.mongodb.net/?retryWrites=true&w=majority&appName=wikiClusterBusinessperson"
client = MongoClient(uri)
db = client['wikidata_json']
collection = db['businessperson']
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# Cell In[27], line 3
#       1 from pymongo.mongo_client import MongoClient
#       2 uri = "mongodb+srv://aniruddha:HFH0ZHWPs0QgbJqZ@wikiclusterbusinesspers.g6alv.mongodb.net/?retryWrites=true&w=majority&appName=wikiClusterBusinessperson"
# ----> 3 client = MongoClient(uri)
#       4 db = client['wikidata_json']
#       5 collection = db['businessperson']
#
# File ~/miniconda3/envs/nl_proj_env/lib/python3.9/site-packages/pymongo/mongo_client.py:774, in MongoClient.__init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     770 if timeout is not None:
#     771     timeout = common.validate_timeout_or_none_or_zero(
#     772         keyword_opts.cased_key("connecttimeoutms"), timeout
#     773     )
# --> 774 res = uri_parser.parse_uri(
#     775     entity,
#     776     port,
#     777     validate=True,
#     778     warn=True,
#     779     normalize=False,
#     780     connect_timeout=timeout,
#     781     srv_service_name=srv_service_name,
#     782     srv_max_hosts=srv_max_hosts,
#     783 )
#     784 seeds.update(res["nodelist"])
#     785 username = res["username"] or username
#
# File ~/miniconda3/envs/nl_proj_env/lib/python3.9/site-packages/pymongo/uri_parser.py:542, in parse_uri(uri, default_port, validate, warn, normalize, connect_timeout, srv_service_name, srv_max_hosts)
#     540 connect_timeout = connect_timeout or options.get("connectTimeoutMS")
#     541 dns_resolver = _SrvResolver(fqdn, connect_timeout, srv_service_name, srv_max_hosts)
# --> 542 nodes = dns_resolver.get_hosts()
#     543 dns_options = dns_resolver.get_options()
#     544 if dns_options:
#
# File ~/miniconda3/envs/nl_proj_env/lib/python3.9/site-packages/pymongo/srv_resolver.py:140, in _SrvResolver.get_hosts(self)
#     139 def get_hosts(self) -> list[tuple[str, Any]]:
# --> 140     _, nodes = self._get_srv_response_and_hosts(True)
#     141     return nodes
#
# File ~/miniconda3/envs/nl_proj_env/lib/python3.9/site-packages/pymongo/srv_resolver.py:120, in _SrvResolver._get_srv_response_and_hosts(self, encapsulate_errors)
#     117 def _get_srv_response_and_hosts(
#     118     self, encapsulate_errors: bool
#     119 ) -> tuple[resolver.Answer, list[tuple[str, Any]]]:
# --> 120     results = self._resolve_uri(encapsulate_errors)
#     122     # Construct address tuples
#     123     nodes = [
#     124         (maybe_decode(res.target.to_text(omit_final_dot=True)), res.port) for res in results
#     125     ]
#
# File ~/miniconda3/envs/nl_proj_env/lib/python3.9/site-packages/pymongo/srv_resolver.py:114, in _SrvResolver._resolve_uri(self, encapsulate_errors)
#     112         raise
#     113     # Else, raise all errors as ConfigurationError.
# --> 114     raise ConfigurationError(str(exc)) from None
#     115 return results
#
# ConfigurationError: module 'httpcore' has no attribute 'NetworkBackend'

# %%
import json

parent_dir = "./Data/English_Labelled_Wikidata_businessperson/"

for i in range(1, 5):
    with open(parent_dir+"en_labelled_part"+ str(i)+".json") as f:
        data = json.load(f)
        print("Loaded JSON file for Part " + str(i))
        # Convert each entity to a format MongoDB can store
        documents = [{**{"_id": key}, **value} for key, value in data.items()]
        collection.insert_many(documents)
        print("Added data from Part " + str(i) + " to Database")
# Out:
# Loaded JSON file for Part 1
# Loaded JSON file for Part 2
# Loaded JSON file for Part 3
# Loaded JSON file for Part 4

# %%
print("Creating Index based on Given name")
# Index 'given name' for fast search
collection.create_index("given name")
collection.create_index("Commons category")
# Out:
# Creating Index based on Given name
# 'given name_1'

# %%
results = collection.find({"given name": "John"})
for result in results:
    print(result)
    print("\n")
# Out:
# {'_id': 'Q9317', 'father': ['John Neville Keynes'], 'mother': ['Florence Ada Keynes'], 'Commons category': ['John Maynard Keynes'], 'Library of Congress authority ID': ['n79004113'], 'VIAF ID': ['29551966'], 'ISNI': ['0000000121258885'], 'occupation': ['economist', 'mathematician', 'politician', 'philosopher', 'professor', 'diplomat', 'non-fiction writer', 'businessperson', 'author'], 'GND ID': ['118561804'], 'place of birth': ['Cambridge'], 'country of citizenship': ['United Kingdom', 'United Kingdom of Great Britain and Ireland'], 'date of birth': [{'time': '+1883-06-05T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}], 'date of death': [{'time': '+1946-04-21T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}], 'NDL Authority ID': ['00445583'], 'movement': ['Bloomsbury Group'], 'NL CR AUT ID': ['jo20010083125'], "topic's main category": ['Category:John Maynard Keynes'], 'instance of': ['human'], 'spouse': ['Lydia Lopokova'], 'Freebase ID': ['/m/09gnn'], 'educated at': ['Eton College', "King's College", 'University of Cambridge', "St Faith's School"], 'CANTIC ID (former scheme)': ['a10108798'], 'award received': ['Companion of the Order of the Bath', 'Adam Smith Prize', 'Fellow of the Econometric Society', 'Fellow of the British Academy', 'doctor honoris causa from the University of Paris'], 'Open Plaques subject ID': ['295'], 'given name': ['John', 'Maynard'], 'MacTutor biography ID': ['Keynes'], 'member of': ['Royal Swedish Academy of Sciences', 'British Academy', 'American Academy of Arts and Sciences', 'Econometric Society'], 'Nationale Thesaurus voor Auteursnamen ID': ['068422806'], 'Munzinger person ID': ['00000000105'], 'Perlentaucher ID': ['john-maynard-keynes'], 'place of death': ['Firle'], 'Digitale Bibliotheek voor de Nederlandse Letteren author ID': ['keyn003'], 'NNDB people ID': ['248/000024176'], 'National Portrait Gallery (London) person ID': ['mp02535'], 'GTAA ID': ['118149'], 'Project Gutenberg author ID': ['6280'], 'SELIBR ID': ['193420'], 'Libraries Australia ID': ['35268961'], 'NCL ID': ['000497330'], 'described by source': ['Great Soviet Encyclopedia (1969–1978)', 'Armenian Soviet Encyclopedia', 'Obálky knih', 'Great Soviet Encyclopedia (1926–1947)'], 'zbMATH author ID': ['keynes.john-maynard'], 'Commons gallery': ['John Maynard Keynes'], 'Gran Enciclopèdia Catalana ID (former scheme)': ['0035584'], 'ODIS ID': ['PS_118734'], 'NLA Trove people ID': ['890519'], 'FAST ID': ['29862'], 'National Library of Spain ID': ['XX1021025'], 'Open Library ID': ['OL33956A'], 'Great Russian Encyclopedia Online ID (old version)': ['2058996'], 'member of political party': ['Liberal Party'], 'LibriVox author ID': ['9726'], 'UK National Archives ID': ['F256804'], 'Hansard (1803–2005) ID': ['mr-john-keynes'], 'InPhO ID': ['thinker/3361'], 'nominated for': ['Nobel Peace Prize', 'Nobel Peace Prize', 'Nobel Peace Prize'], 'National Library of Greece ID': ['62716'], 'sibling': ['Margaret Neville Keynes', 'Geoffrey Keynes'], 'Vatican Library ID (former scheme)': ['ADV10211828'], 'NUKAT ID': ['n96100888'], 'Portuguese National Library author ID': ['50719'], 'Treccani ID': ['john-maynard-keynes'], 'SNAC ARK ID': ['w6q81dnz'], 'Find a Grave memorial ID': ['13917737'], 'Cultureel Woordenboek ID': ['economie/john-maynard-keynes'], 'Persée author ID': ['58075'], 'openMLOL author ID': ['23878'], 'Mathematics Genealogy Project ID': ['210789'], 'WikiTree person ID': ['Keynes-28'], 'Babelio author ID': ['118455'], 'Nobel Prize People Nomination ID': ['4817'], 'BNMM authority ID': ['000026162'], 'notable work': ['The General Theory of Employment, Interest and Money', 'Indian Currency and Finance', 'The Economic Consequences of the Peace', 'A Treatise on Probability', 'A Treatise on Money'], 'SHARE Catalogue author ID': ['34099'], 'WeRelate person ID': ['John_Maynard_Keynes_(1)'], 'Encycl ...
#
#
# {'_id': 'Q11702', 'sex or gender': ['male'], 'occupation': ['politician', 'entrepreneur', 'businessperson', 'business executive'], 'country of citizenship': ['United States of America'], 'Commons category': ['John Boehner'], 'position held': ['Republican Conference Chairman of the United States House of Representatives', 'Speaker of the United States House of Representatives', 'Ohio state representative', 'member of the United States House of Representatives', 'member of the United States House of Representatives', 'member of the United States House of Representatives', 'member of the United States House of Representatives', 'member of the United States House of Representatives', 'member of the United States House of Representatives', 'member of the United States House of Representatives', 'member of the United States House of Representatives', 'member of the United States House of Representatives', 'member of the United States House of Representatives', 'member of the United States House of Representatives', 'member of the United States House of Representatives', 'member of the United States House of Representatives'], 'member of political party': ['Republican Party'], 'educated at': ['Xavier University', 'Moeller High School'], 'instance of': ['human'], 'date of birth': [{'time': '+1949-11-17T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}], 'image': ['John Boehner official portrait.jpg'], 'Freebase ID': ['/m/039rwf'], 'Library of Congress authority ID': ['no2011146451'], 'VIAF ID': ['177323776'], 'place of birth': ['Reading'], 'signature': ['John Boehner Signature.svg'], 'official website': ['http://www.johnboehner.com/'], 'military branch': ['United States Navy'], 'described by source': ['Lentapedia'], 'religion or worldview': ['Catholic Church'], 'given name': ['John', 'Andrew'], 'US Congress Bio ID': ['B000589'], 'GTAA ID': ['226194'], 'PolitiFact people and groups ID': ['john-boehner'], 'FAST ID': ['1912017'], 'Encyclopædia Britannica Online ID': ['biography/John-A-Boehner', 'biography/John-Boehner'], 'work location': ['Washington, D.C.', 'Columbus'], 'C-SPAN person ID': ['johnboehner'], 'NNDB people ID': ['378/000032282'], 'New York Times topic ID': ['person/john-boehner'], 'languages spoken, written or signed': ['English'], 'name in native language': [{'text': 'John Boehner', 'language': 'en'}], 'Vote Smart candidate ID': ['27015'], 'US Federal Election Commission ID': ['H0OH08029'], 'SNAC ARK ID': ['w6379ndt'], 'family name': ['Boehner'], 'different from': ['John Byner'], 'writing language': ['English'], 'Munzinger person ID': ['00000028459'], 'Brockhaus Enzyklopädie online ID': ['boehner-john-andrew'], 'Store norske leksikon ID': ['John_Boehner'], 'X username': ['speakerboehner', 'SpeakerBoehner'], 'Facebook username': ['SpeakerJohnBoehner'], 'award received': ['Dr. Nathan Davis Award for United States Representatives', 'Laetare Medal', 'Grand Cordon of the Order of the Rising Sun'], 'Ballotpedia ID': ['John_Boehner'], 'GeneaStar person ID': ['johnandrewboehnerj'], 'Alexander Turnbull Library ID': ['287953'], 'social media followers': [{'amount': '+1357595', 'unit': '1'}, {'amount': '+1375235', 'unit': '1'}, {'amount': '+1313079', 'unit': '1'}, {'amount': '+1290678', 'unit': '1'}], 'Trading Card Database person ID': ['144199'], 'U.S. National Archives Identifier': ['185831519'], 'Podchaser creator ID': ['107aWcKRQu'], 'AllSides ID': ['john-boehner'], 'Lex ID': ['John_Boehner'], 'Prabook ID': ['724944'], 'RationalWiki ID': ['John_Boehner'], 'OpenSanctions ID': ['Q11702'], 'C-SPAN person numeric ID': ['16740'], 'Geni.com profile ID': ['6000000024617279597'], 'CineMagia person ID': ['277134'], 'United States House of Representatives ID': ['9538'], 'Political Graveyard politician ID': ['boe-boggess.html#604.24.05'], 'ICPSR Personal Names Authority List ID': ['13761'], 'WorldCat Entities ID': ['E39PBJdh3fHWhvrY8jD6Gj6xjC'], 'IMDb ID': ['nm21 ...
#
#
# {'_id': 'Q22686', 'Commons category': ['Donald Trump'], 'VIAF ID': ['49272447'], 'ISNI': ['0000000108986765'], 'country of citizenship': ['United States of America'], 'Library of Congress authority ID': ['n85387872'], 'GND ID': ['118834312'], 'IMDb ID': ['nm0874339'], 'signature': ['Donald Trump Signature.svg', 'Signatures of President Donald Trump, Rodney Scott and Brian Hastings on a piece of paper placed on the Texas-Mexico border wall on January 12, 2021 - (50849560102) (cropped).jpg'], 'IdRef ID': ['145942198'], 'Bibliothèque nationale de France ID': ['12195835j'], 'NDL Authority ID': ['00476339'], 'native language': ['English'], 'place of birth': ['Jamaica Hospital Medical Center', 'New York City'], 'occupation': ['business magnate', 'investor', 'restaurateur', 'politician', 'game show host', 'real estate entrepreneur', 'television producer', 'film producer', 'writer', 'actor', 'chief executive officer', 'conspiracy theorist', 'merchant', 'businessperson', 'entrepreneur'], 'field of work': ['real property', 'government', 'television production', 'politics', 'commerce'], 'educated at': ['Fordham University', 'The Wharton School', 'The Kew-Forest School', 'New York Military Academy', 'University of Pennsylvania'], 'academic degree': ['Bachelor of Science'], 'religion or worldview': ['Presbyterianism', 'Nondenominational Christianity'], 'father': ['Fred Trump'], 'child': ['Donald Trump Jr.', 'Ivanka Trump', 'Eric Trump', 'Tiffany Trump', 'Barron Trump'], 'instance of': ['human'], 'date of birth': [{'time': '+1946-06-14T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, {'time': '+1946-00-00T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 9, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}, {'time': '+1946-06-00T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 10, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}], 'Freebase ID': ['/m/0cqt90'], 'sex or gender': ['male'], "topic's main category": ['Category:Donald Trump'], 'official website': ['https://www.donaldjtrump.com', 'https://www.45office.com'], 'given name': ['Donald', 'John'], 'Nationale Thesaurus voor Auteursnamen ID': ['073829463'], 'Munzinger person ID': ['00000019560'], 'NNDB people ID': ['363/000022297'], 'Union List of Artist Names ID': ['500082105'], 'GTAA ID': ['162022'], 'genealogics.org person ID': ['I00582316'], 'plaque image': ['Donald Trump star Hollywood Walk of Fame.JPG'], 'US Federal Election Commission ID': ['P80001571'], 'family name': ['Trump'], 'languages spoken, written or signed': ['English'], 'name in native language': [{'text': 'Donald Trump', 'language': 'en'}], 'Rotten Tomatoes ID': ['celebrity/donald_trump', 'celebrity/donald_j_trump'], 'number of children': [{'amount': '+5', 'unit': '1'}], 'handedness': ['right-handedness'], 'significant event': ['Donald Trump 2016 presidential campaign', 'Donald Trump 2000 presidential campaign', 'inauguration of Donald Trump', 'Donald Trump and Billy Bush recording controversy', 'Donald Trump 2020 presidential campaign', 'United States withdrawal from the Paris Agreement', 'United States withdrawal from Iran Deal', 'United States–Mexico–Canada Agreement', '2017 dismissal of U.S. attorneys', 'first impeachment inquiry against Donald Trump', 'second impeachment of Donald Trump', 'Obama spying contra-Trump allegations', 'attempted assassination of Donald Trump'], 'X username': ['realDonaldTrump', 'POTUS45', 'POTUS'], 'Instagram username': ['realdonaldtrump'], 'Facebook username': ['DonaldTrump', 'POTUS45', 'POTUS'], 'PolitiFact people and groups ID': ['donald-trump'], 'FAST ID': ['174117'], 'Ballotpedia ID': ['Donald_Trump'], 'birth name': [{'text': 'Donald John Trump', 'language': 'en'}], 'Geni.com profile ID': ['6000000007106626344'], 'award received': ['star on Hollywood Walk of Fame', 'Jewish National Fund Tree of Life Award', 'Ellis Island Medal of Honor', 'Time Person o ...

# %%
results

# %%
documents
# Out:
# [{'_id': 'Q21863',
#   'Commons category': ['Eleanor Coade'],
#   'VIAF ID': ['95698812'],
#   'sex or gender': ['female'],
#   'occupation': ['businessperson', 'sculptor', 'inventor'],
#   'date of birth': [{'time': '+1733-06-03T00:00:00Z',
#     'timezone': 0,
#     'before': 0,
#     'after': 0,
#     'precision': 11,
#     'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}],
#   'date of death': [{'time': '+1821-11-16T00:00:00Z',
#     'timezone': 0,
#     'before': 0,
#     'after': 0,
#     'precision': 11,
#     'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}],
#   'instance of': ['human'],
#   'place of birth': ['Exeter'],
#   'place of death': ['Camberwell'],
#   'CLARA-ID': ['16514'],
#   'given name': ['Eleanor'],
#   'Union List of Artist Names ID': ['500002974'],
#   'member of': ['Society of Artists'],
#   'British Museum person or institution ID': ['198786'],
#   'Library of Congress authority ID': ['n88003325'],
#   'ISNI': ['0000000117766481'],
#   'FAST ID': ['239328'],
#   'place of burial': ['Bunhill Fields Burial Ground'],
#   'Benezit ID': ['B00039623'],
#   'Commons Creator page': ['Eleanor Coade'],
#   'Artnet artist ID': ['eleanor-coade'],
#   'RA Collections ID': ['20991'],
#   'Oxford Dictionary of National Biography ID': ['37296'],
#   'Royal Academy new identifier': ['eleanor-coade'],
#   "Grace's Guide ID": ['Eleanor_Coade'],
#   'family name': ['Coade'],
#   'country of citizenship': ['United Kingdom of Great Britain and Ireland',
#    'Kingdom of Great Britain'],
#   'archINFORM person/group ID': ['13193'],
#   'Art UK artist ID': ['coade-eleanor-17331821'],
#   'Dictionary of Sculptors in Britain ID': ['561'],
#   'Europeana entity': ['agent/base/2066'],
#   'Grove Art Online ID': ['T018296'],
#   'WikiTree person ID': ['Coade-79'],
#   'Freebase ID': ['/m/0fw3y7'],
#   'copyright status as a creator': ['copyrights on works have expired'],
#   'GND ID': ['1214653545'],
#   'AKL Online artist ID': ['10166703'],
#   'Met Constituent ID': ['79212'],
#   'askArt person ID': ['11201865'],
#   'Oxford Reference overview ID': ['20110803095619973'],
#   'WorldCat Entities ID': ['E39PBJm4Q9PcRBt9JtTyrX7WDq']},
#  {'_id': 'Q21901',
#   'sex or gender': ['female'],
#   'VIAF ID': ['52548959'],
#   'GND ID': ['121579980'],
#   'place of birth': ['Shelbyville'],
#   'country of citizenship': ['United States of America'],
#   'instance of': ['human'],
#   'date of birth': [{'time': '+1839-03-08T00:00:00Z',
#     'timezone': 0,
#     'before': 0,
#     'after': 0,
#     'precision': 11,
#     'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#    {'time': '+1839-01-01T00:00:00Z',
#     'timezone': 0,
#     'before': 0,
#     'after': 0,
#     'precision': 9,
#     'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}],
#   'date of death': [{'time': '+1913-08-03T00:00:00Z',
#     'timezone': 0,
#     'before': 0,
#     'after': 0,
#     'precision': 11,
#     'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#    {'time': '+1913-01-01T00:00:00Z',
#     'timezone': 0,
#     'before': 0,
#     'after': 0,
#     'precision': 9,
#     'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}],
#   'Freebase ID': ['/m/05_gln'],
#   'occupation': ['inventor', 'businessperson'],
#   'given name': ['Josephine'],
#   'image': ['Stamps of Romania, 2013-34.jpg'],
#   'place of death': ['Chicago'],
#   'award received': ['National Inventors Hall of Fame'],
#   'National Inventors Hall of Fame ID': ['josephine-garis-cochran'],
#   'NNDB people ID': ['166/000165668'],
#   'family name': ['Cochrane', 'Garis'],
#   'Find a Grave memorial ID': ['10185360'],
#   'cause of death': ['cerebrovascular disease'],
#   'name in native language': [{'text': 'Josephine Lorelai Coachrana',
#     'language': 'en'}],
#   'Geni.com profile ID': ['6000000115140476881'],
#   'mother': ['Irene Fitch Garis'],
#   'Prabook ID': ['2282080'],
#   'on focus list of Wikimedia project': ['Wikipedia:Vital articles/Level/4'],
#   'Enciclopedia delle donne ID': ['josephine-garis-cochran'],
#   'FemBio ID': ['31205'],
#   'Library of Congress authority ID': ['no2023036623'],
#   'WikiTree person ID': ['Garis-1']},
#  {'_id': 'Q22290',
#   'sex or gender': ['female'],
#   'Commons category': ['Olympia Snowe'],
#   'country of citizenship': ['United States of America'],
#   'Library of Congress authority ID': ['n99037269'],
#   'VIAF ID': ['55944065'],
#   'occupation': ['politician', 'businessperson'],
#   'position held': ['member of the United States House of Representatives',
#    'member of the State Senate of Maine',
#    'member of the Maine House of Representatives',
#    'delegate',
#    'delegate',
#    'member of the United States House of Representatives',
#    'member of the United States House of Representatives',
#    'United States senator',
#    'United States senator',
#    'United States senator',
#    'United States senator',
#    'United States senator',
#    'United States senator',
#    'United States senator',
#    'United States senator',
#    'United States senator',
#    'member of the United States House of Representatives',
#    'member of the United States House of Representatives',
#    'member of the United States House of Representatives',
#    'member of the United States House of Representatives',
#    'member of the United States House of Representatives',
#    'member of the United States House of Representatives'],
#   'date of birth': [{'time': '+1947-02-21T00:00:00Z',
#     'timezone': 0,
#     'before': 0,
#     'after': 0,
#     'precision': 11,
#     'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}],
#   'member of political party': ['Republican Party'],
#   'educated at': ['University of Maine',
#    'Bates College',
#    'Edward Little High School',
#    'Saint Basil Academy'],
#   'instance of': ['human'],
#   'image': ['Olympia Snowe official photo 2010 edit.jpg'],
#   'Freebase ID': ['/m/020yg2'],
#   'place of birth': ['Augusta'],
#   'given name': ['Olympia', 'Jean'],
#   'US Congress Bio ID': ['S000663'],
#   'signature': ['Olympia Snowe Signature.svg'],
#   'languages spoken, written or signed': ['English'],
#   'Commons gallery': ['Olympia Snowe'],
#   'C-SPAN person ID': ['olympiasnowe'],
#   'name in native language': [{'text': 'Olympia Snowe', 'language': 'en'}],
#   'work location': ['Washington, D.C.', 'Augusta'],
#   'award received': ["Maine Women's Hall of Fame"],
#   'WikiTree person ID': ['Bouchles-1'],
#   'Vote Smart candidate ID': ['26885'],
#   'Quora topic ID': ['Olympia-Snowe'],
#   'spouse': ['Peter T. Snowe', 'John R. McKernan'],
#   'ISNI': ['0000000374236836'],
#   'NNDB people ID': ['298/000032202'],
#   'Encyclopædia Britannica Online ID': ['biography/Olympia-Snowe'],
#   'religion or worldview': ['Eastern Orthodoxy'],
#   'IMDb ID': ['nm1995785'],
#   'employer': ['William Cohen'],
#   "topic's main category": ['Category:Olympia Snowe'],
#   'NL CR AUT ID': ['mzk2005279218'],
#   'GND ID': ['1180778642'],
#   'writing language': ['English'],
#   'described by source': ['Obálky knih'],
#   'family name': ['Snowe'],
#   'FAST ID': ['433640'],
#   'X username': ['SenatorSnowe'],
#   'social media followers': [{'amount': '+7176', 'unit': '1'},
#    {'amount': '+7250', 'unit': '1'}],
#   'SNAC ARK ID': ['w6b01xt7'],
#   'J9U ID': ['987007363300805171'],
#   'OpenSanctions ID': ['Q22290'],
#   'C-SPAN person numeric ID': ['3260'],
#   'Prabook ID': ['883473'],
#   'United States House of Representatives ID': ['21955'],
#   'CineMagia person ID': ['75520'],
#   'WorldCat Entities ID': ['E39PBJbWrQmTg9RcFQcMMgv4MP'],
#   'Ballotpedia ID': ['Olympia_Snowe']},
#  {'_id': 'Q22401',
#   'place of burial': ['Passy Cemetery'],
#   'place of birth': ['Paris'],
#   'Commons category': ['Henri Farman'],
#   'VIAF ID': ['56598466'],
#   'ISNI': ['0000000055095386'],
#   'country of citizenship': ['France'],
#   'Library of Congress authority ID': ['n2007086367'],
#   'GND ID': ['135955696'],
#   'place of death': ['Paris'],
#   'image': ['Henri Farman (1907) - Agence Rol btv1b53225152f.jpg'],
#   'date of birth': [{'time': '+1874-05-26T00:00:00Z',
#     'timezone': 0,
#     'before': 0,
#     'after': 0,
#     'precision': 11,
#     'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}],
#   'date of death': [{'time': '+1958-07-17T00:00:00Z',
#     'timezone': 0,
#     'before': 0,
#     'after': 0,
#     'precision': 11,
#     'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}],
#   'instance of': ['human'],
#   'Freebase ID': ['/m/0jn8v'],
#   'Bibliothèque nationale de France ID': ['10269486k'],
#   'occupation': ['sport cyclist',
#    'aerospace engineer',
#    'engineer',
#    'racing automobile driver',
#    'aircraft pilot',
#    'businessperson'],
#   'given name': ['Henri'],
#   'notable work': ['Souvenirs et Récits contés le 28 novembre 1933'],
#   'sport': ['track cycling'],
#   'described by source': ['Great Soviet Encyclopedia (1969–1978)',
#    'Armenian Soviet Encyclopedia'],
#   'Gran Enciclopèdia Catalana ID (former scheme)': ['0026056'],
#   'Commons gallery': ['Henry Farman'],
#   'Cycling Archives cyclist ID': ['14841'],
#   'FAST ID': ['1691419'],
#   'nominated for': ['Nobel Prize in Physics'],
#   'sibling': ['Maurice Farman', 'Richard Farman'],
#   'name in native language': [{'text': 'Henri Farman', 'language': 'fr'}],
#   'Nobel Prize People Nomination ID': ['2912'],
#   'NE.se ID': ['henri-farman'],
#   'Early Aviators people ID': ['efarman'],
#   'Encyclopædia Britannica Online ID': ['biography/Henri-Farman'],
#   'Oxford Dictionary of National Biography ID': ['58409'],
#   'Encyclopædia Universalis ID': ['henri-farman'],
#   'family name': ['Farman'],
#   'Great Russian Encyclopedia Online ID (old version)': ['4706376'],
#   "topic's main category": ['Category:Henri Farman'],
#   'languages spoken, written or signed': ['French'],
#   'IdRef ID': ['164531408'],
#   'sex or gender': ['male'],
#   "Grace's Guide ID": ['Henry_Farman'],
#   'gravsted.dk ID': ['henrifarman'],
#   'Poincaré Papers person ID': ['15298'],
#   'Brockhaus Enzyklopädie online ID': ['farman-henri'],
#   'Find a Grave memorial ID': ['7163'],
#   'Deutsche Biographie (GND) ID': ['135955696'],
#   'NUKAT ID': ['n2012042928'],
#   'Museo Galileo authority ID': ['171973'],
#   'Trading Card Database person ID': ['182318'],
#   'birth name': [{'text': 'Harry Edgar Mudford Farman', 'language': 'en'}],
#   'Proleksis enciklopedija ID': ['5342'],
#   'Lex ID': ['Henri_Farman'],
#   'Store norske leksikon ID': ['Henri_og_Maurice_Farman', 'Henri_Farman'],
#   'Prabook ID': ['2341083'],
#   'Google Arts & Culture entity ID': ['m0jn8v'],
#   'WikiTree person ID': ['Farman-199'],
#   'Gran Enciclopèdia Catalana ID': ['henri-farman'],
#   'museum-digital person ID': ['6963'],
#   'WorldCat Entities ID': ['E39PBJgCJwKVPwgWkpGvDfdRKd'],
#   'award received': ["Great Gold medal of the Société d'Encouragement au Progrès"]},
#  {'_id': 'Q22677',
#   'sex or gender': ['male'],
#   'occupation': ['writer', 'computer scientist', 'businessperson', 'inventor'],
#   'country of citizenship': ['United States of America'],
#   'VIAF ID': ['185004300'],
#   'Library of Congress authority ID': ['no2011141086'],
#   'image': ['Michael Hart and Gregory Newby at HOPE Conference.jpg',
#    'Michael Hart at HOPE Conference (cropped).jpg'],
#   'Commons category': ['Michael S. Hart'],
#   'date of birth': [{'time': '+1947-03-08T00:00:00Z',
#     'timezone': 0,
#     'before': 0,
#     'after': 0,
#     'precision': 11,
#     'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}],
#   'date of death': [{'time': '+2011-09-06T00:00:00Z',
#     'timezone': 0,
#     'before': 0,
#     'after': 0,
#     'precision': 11,
#     'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}],
#   'instance of': ['human'],
#   'place of birth': ['Tacoma'],
#   'place of death': ['Urbana'],
#   'Freebase ID': ['/m/01437q'],
#   'given name': ['Michael'],
#   'cause of death': ['myocardial infarction'],
#   'educated at': ['University of Illinois Urbana–Champaign'],
#   'manner of death': ['natural causes'],
#   'NNDB people ID': ['606/000275778'],
#   'Theatricalia person ID': ['way'],
#   'Project Gutenberg author ID': ['958'],
#   'Encyclopædia Britannica Online ID': ['biography/Michael-Stern-Hart'],
#   'family name': ['Hart'],
#   'official website': ['https://pglaf.org/hart/'],
#   'Quora topic ID': ['Michael-S-Hart-author', 'Michael-Hart-46'],
#   'SELIBR ID': ['346780'],
#   'Online Books Page author ID': ['Hart, Michael, 1947-2011'],
#   'ISNI': ['000000035634776X'],
#   'Libris-URI': ['sq47d5mb0g655ps'],
#   'Canadiana Name Authority ID': ['ncf10287723'],
#   'J9U ID': ['987007394988905171'],
#   'Pontifical University of Salamanca ID': ['1402709'],
#   'WikiTree person ID': ['Hart-22660'],
#   'WorldCat Entities ID': ['E39PBJyMk9RBPFGd3R3KGJG4MP']},
#  {'_id': 'Q22686',
#   'Commons category': ['Donald Trump'],
#   'VIAF ID': ['49272447'],
#   'ISNI': ['0000000108986765'],
#   'country of citizenship': ['United States of America'],
#   'Library of Congress authority ID': ['n85387872'],
#   'GND ID': ['118834312'],
#   'IMDb ID': ['nm0874339'],
#   'signature': ['Donald Trump Signature.svg',
#    'Signatures of President Donald Trump, Rodney Scott and Brian Hastings on a piece of paper placed on the Texas-Mexico border wall on January 12, 2021 - (50849560102) (cropped).jpg'],
#   'IdRef ID': ['145942198'],
#   'Bibliothèque nationale de France ID': ['12195835j'],
#   'NDL Authority ID': ['00476339'],
#   'native language': ['English'],
#   'place of birth': ['Jamaica Hospital Medical Center', 'New York City'],
#   'occupation': ['business magnate',
#    'investor',
#    'restaurateur',
#    'politician',
#    'game show host',
#    'real estate entrepreneur',
#    'television producer',
#    'film producer',
#    'writer',
#    'actor',
#    'chief executive officer',
#    'conspiracy theorist',
#    'merchant',
#    'businessperson',
#    'entrepreneur'],
#   'field of work': ['real property',
#    'government',
#    'television production',
#    'politics',
#    'commerce'],
#   'educated at': ['Fordham University',
#    'The Wharton School',
#    'The Kew-Forest School',
#    'New York Military Academy',
#    'University of Pennsylvania'],
#   'academic degree': ['Bachelor of Science'],
#   'religion or worldview': ['Presbyterianism',
#    'Nondenominational Christianity'],
#   'father': ['Fred Trump'],
#   'child': ['Donald Trump Jr.',
#    'Ivanka Trump',
#    'Eric Trump',
#    'Tiffany Trump',
#    'Barron Trump'],
#   'instance of': ['human'],
#   'date of birth': [{'time': '+1946-06-14T00:00:00Z',
#     'timezone': 0,
#     'before': 0,
#     'after': 0,
#     'precision': 11,
#     'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#    {'time': '+1946-00-00T00:00:00Z',
#     'timezone': 0,
#     'before': 0,
#     'after': 0,
#     'precision': 9,
#     'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#    {'time': '+1946-06-00T00:00:00Z',
#     'timezone': 0,
#     'before': 0,
#     'after': 0,
#     'precision': 10,
#     'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}],
#   'Freebase ID': ['/m/0cqt90'],
#   'sex or gender': ['male'],
#   "topic's main category": ['Category:Donald Trump'],
#   'official website': ['https://www.donaldjtrump.com',
#    'https://www.45office.com'],
#   'given name': ['Donald', 'John'],
#   'Nationale Thesaurus voor Auteursnamen ID': ['073829463'],
#   'Munzinger person ID': ['00000019560'],
#   'NNDB people ID': ['363/000022297'],
#   'Union List of Artist Names ID': ['500082105'],
#   'GTAA ID': ['162022'],
#   'genealogics.org person ID': ['I00582316'],
#   'plaque image': ['Donald Trump star Hollywood Walk of Fame.JPG'],
#   'US Federal Election Commission ID': ['P80001571'],
#   'family name': ['Trump'],
#   'languages spoken, written or signed': ['English'],
#   'name in native language': [{'text': 'Donald Trump', 'language': 'en'}],
#   'Rotten Tomatoes ID': ['celebrity/donald_trump', 'celebrity/donald_j_trump'],
#   'number of children': [{'amount': '+5', 'unit': '1'}],
#   'handedness': ['right-handedness'],
#   'significant event': ['Donald Trump 2016 presidential campaign',
#    'Donald Trump 2000 presidential campaign',
#    'inauguration of Donald Trump',
#    'Donald Trump and Billy Bush recording controversy',
#    'Donald Trump 2020 presidential campaign',
#    'United States withdrawal from the Paris Agreement',
#    'United States withdrawal from Iran Deal',
#    'United States–Mexico–Canada Agreement',
#    '2017 dismissal of U.S. attorneys',
#    'first impeachment inquiry against Donald Trump',
#    'second impeachment of Donald Trump',
#    'Obama spying contra-Trump allegations',
#    'attempted assassination of Donald Trump'],
#   'X username': ['realDonaldTrump', 'POTUS45', 'POTUS'],
#   'Instagram username': ['realdonaldtrump'],
#   'Facebook username': ['DonaldTrump', 'POTUS45', 'POTUS'],
#   'PolitiFact people and groups ID': ['donald-trump'],
#   'FAST ID': ['174117'],
#   'Ballotpedia ID': ['Donald_Trump'],
#   'birth name': [{'text': 'Donald John Trump', 'language': 'en'}],
#   'Geni.com profile ID': ['6000000007106626344'],
#   'award received': ['star on Hollywood Walk of Fame',
#    'Jewish National Fund Tree of Life Award',
#    'Ellis Island Medal of Honor',
#    'Time Person of the Year',
#    'Doublespeak Award',
#    'Gaming Hall of Fame',
#    'WWE Hall of Fame',
#    'King Abdulaziz Medal',
#    'Presidential Order of Excellence',
#    'Golden Raspberry Award for Worst Supporting Actor',
#    'Doublespeak Award',
#    'Ig Nobel Prize',
#    'Time 100',
#    'Order of the Mohammedi',
#    'Order of Freedom',
#    'Order of King Abdulaziz al Saud',
#    'Financial Times Person of the Year',
#    'Time 100',
#    'Time 100',
#    'Time 100',
#    'Time 100',
#    'Time 100'],
#   'National Library of Israel ID (old)': ['000477325'],
#   'mother': ['Mary Anne MacLeod Trump'],
#   'relative': ['John G. Trump',
#    'Elizabeth Christ',
#    'Jared Kushner',
#    'Lara Trump',
#    'Vanessa Trump',
#    'Mary L. Trump',
#    'John Whitney Walter'],
#   'residence': ['Trump Tower',
#    'Mar-a-Lago',
#    'White House',
#    'Manhattan',
#    'New York',
#    'Queens',
#    'Palm Beach',
#    'Jamaica Estates'],
#   'notable work': ['Trump: The Art of the Deal',
#    'Crippled America',
#    'The Apprentice'],
#   'NACSIS-CAT author ID': ['DA08488604'],
#   'Curlie ID': ['Regional/North_America/United_States/Society_and_Culture/Politics/Candidates_and_Campaigns/President/Candidates/Donald_Trump/'],
#   'C-SPAN person ID': ['donaldtrump'],
#   'Encyclopædia Britannica Online ID': ['biography/Donald-Trump',
#    'biography/Donald-J-Trump'],
#   'described by source': ['Great Encyclopedia of Cyril and Methodius',
#    'Never Enough: Donald Trump and the Pursuit of Success',
#    'Obálky knih',
#    'Too Much and Never Enough',
#    'popular culture'],
#   'CONOR.SI ID': ['74264419'],
#   'NL CR AUT ID': ['jn19990008619'],
#   'SELIBR ID': ['291160'],
#   'Portuguese National Library author ID': ['1297779'],
#   'NUKAT ID': ['n00079388'],
#   'Libraries Australia ID': ['35123886'],
#   'NLA Trove people ID': ['833430'],
#   'Open Library ID': ['OL398175A'],
#   'Rodovid ID': ['163827'],
#   'National Library of Latvia ID': ['000084831'],
#   'NSK ID': ['000386800'],
#   'Discogs artist ID': ['385236'],
#   'National Library of Spain ID': ['XX1127639'],
#   'AlloCiné person ID': ['35464'],
#   'ČSFD person ID': ['14676'],
#   'AllMovie person ID': ['p71941'],
#   'Swedish Film Database person ID': ['216656'],
#   'nickname': [{'text': 'The Donald', 'language': 'en'}],
#   'RSL ID (person)': ['000018418'],
#   "topic's main template": ['Template:Donald Trump series',
#    'Template:Donald Trump'],
#   'position held': ['President of the United States',
#    'President-elect of the United States',
#    'chairperson',
#    'president',
#    'director'],
#   'TV.com ID': ['people/donald-trump'],
#   'MusicBrainz artist ID': ['13dc1600-baca-4aaf-beee-fb000b66ae24'],
#   'Google+ ID': ['+DonaldJTrumpforPresident'],
#   'Kinopoisk person ID': ['39272'],
#   'Scope.dk person ID': ['2831'],
#   'PORT person ID': ['201431'],
#   'Internet Broadway Database person ID': ['21682'],
#   'net worth': [{'amount': '+3100000000',
#     'unit': 'http://www.wikidata.org/entity/Q4917'},
#    {'amount': '+2500000000', 'unit': 'http://www.wikidata.org/entity/Q4917'}],
#   'WikiTree person ID': ['Trump-66'],
#   'Guardian topic ID': ['us-news/donaldtrump'],
#   'Wall Street Journal topic ID': ['person/T/donald-trump/159'],
#   'NE.se ID': ['donald-trump', 'donald-j-trump'],
#   'New York Times topic ID': ['person/donald-trump'],
#   'mass': [{'amount': '+243',
#     'unit': 'http://www.wikidata.org/entity/Q100995'},
#    {'amount': '+110', 'unit': 'http://www.wikidata.org/entity/Q11570'},
#    {'amount': '+215', 'unit': 'http://www.wikidata.org/entity/Q100995'}],
#   'BiblioNet author ID': ['71248'],
#   "topic's main Wikimedia portal": ['Portal:Donald Trump'],
#   'filmography': ['Donald Trump filmography'],
#   'work location': ['New York City', 'Washington, D.C.'],
#   'Goodreads author ID': ['676'],
#   'pronunciation audio': ['Donald John Trump.oga'],
#   'nominated for': ['Primetime Emmy Award for Outstanding Reality-Competition Program',
#    'Primetime Emmy Award for Outstanding Reality-Competition Program',
#    'Nobel Peace Prize',
#    'Golden Raspberry Award for Worst Supporting Actor',
#    'Golden Raspberry Award for Worst New Star'],
#   'Perlentaucher ID': ['donald-trump'],
#   'National Library of Romania ID': ['000226533'],
#   'NORAF ID': ['97055467'],
#   'height': [{'amount': '+1.90',
#     'unit': 'http://www.wikidata.org/entity/Q11573'},
#    {'amount': '+74', 'unit': 'http://www.wikidata.org/entity/Q218593'},
#    {'amount': '+75', 'unit': 'http://www.wikidata.org/entity/Q218593'},
#    {'amount': '+180.33', 'unit': 'http://www.wikidata.org/entity/Q174728'},
#    {'amount': '+190', 'unit': 'http://www.wikidata.org/entity/Q174728'}],
#   'list of works': ['bibliography of Donald Trump'],
#   'Gran Enciclopèdia Catalana ID (former scheme)': ['22148953'],
#   'National Library of Greece ID': ['265994'],
#   'sibling': ['Maryanne Trump Barry',
#    'Fred Trump Jr.',
#    'Robert Trump',
#    'Elizabeth Trump Grau'],
#   'Commons gallery': ['Donald Trump'],
#   'different from': ['Donald Trump',
#    'Donald Trump III',
#    'Donald Trump Jr.',
#    'Donald Trump'],
#   'Quora topic ID': ['Donald-Trump-politician-business-person',
#    'AMERICAS-45th-PRESIDENT',
#    'Mr-Donald-Trump'],
#   'SNAC ARK ID': ['w6rp0sqg'],
#   'Omni topic ID': ['bd15de4ce31221e011121ec74d334a942dd4e8d2'],
#   'described at URL': ['https://www.whitehouse.gov/administration/president-trump'],
#   'Parlement.com ID': ['vkb1n6dxzovs'],
#   'CCAB ID': ['000883258'],
#   'Vote Smart candidate ID': ['15723'],
#   'Open Plaques subject ID': ['18508'],
#   'Dagens Nyheter topic ID': ['donald-trump'],
#   'BBC Things ID': ['78080d81-2849-497e-bc3a-bf364626456b'],
#   'Commons Creator page': ['Donald Trump'],
#   'member of': ["The World's Billionaires", 'SAG-AFTRA'],
#   'hair color': ['blond hair'],
#   'pseudonym': ['John Barron', 'John Miller', 'The Donald', 'David Dennison'],
#   'Treccani ID': ['donald-trump'],
#   'Babelio author ID': ['97151'],
#   'WeRelate person ID': ['Donald_Trump_(2)'],
#   'Familypedia person ID': ['Donald_John_Trump_(1946)'],
#   'Reddit username': ['the-realDonaldTrump'],
#   'WWE.com superstar ID': ['donald-trump'],
#   'Last.fm ID': ['Donald+Trump'],
#   'Carnegie Hall agent ID': ['91624'],
#   'Encyclopædia Universalis ID': ['donald-trump'],
#   'family': ['family of Donald Trump'],
#   'image': ['Donald Trump official portrait.jpg',
#    'Donald Trump in July 2024 (cropped).jpg'],
#   'TMDB person ID': ['33663'],
#   'UK Parliament thesaurus ID': ['423090'],
#   'SHARE Catalogue author ID': ['133422'],
#   'participant in': ['2018 North Korea–United States Singapore Summit',
#    'Trump–Ukraine scandal',
#    '2016 United States presidential election',
#    '2020 United States presidential election',
#    'World Economic Forum Annual Meeting 2018',
#    'World Economic Forum Annual Meeting 2020',
#    'New York prosecution of Donald Trump',
#    '2024 United States presidential election'],
#   'IAFD male performer ID': ['donaldtrump'],
#   'BNB person ID': ['TrumpDonald1946-'],
#   'archINFORM person/group ID': ['11404'],
#   'Open Media Database person ID': ['33663'],
#   'Courrier international topic ID': ['donald-trump'],
#   'Le Monde ID': ['donald-trump'],
#   'Libris-URI': ['sq47b3tb0qfmqbh'],
#   'Stack Exchange tag': ['https://politics.stackexchange.com/tags/donald-trump'],
#   'owner of': ['Trump World Tower',
#    'Mar-a-Lago',
#    'Trump National Golf Club',
#    'Bonwit Teller Building',
#    'Trump National Golf Club',
#    'Kingdom 5KR'],
#   'Google News topics ID': ['CAAqIggKIhxDQkFTRHdvSkwyMHZNR054ZERrd0VnSmxiaWdBUAE'],
#   'Unz Review author ID': ['TrumpDonaldJ'],
#   'catchphrase': [{'text': "You're fired!", 'language': 'en'},
#    {'text': 'Make America great again', 'language': 'en'},
#    {'text': 'America first', 'language': 'en'}],
#   'Zhihu topic ID': ['20023724'],
#   'Klexikon article ID': ['Donald_Trump'],
#   "L'Express person ID": ['donald-trump'],
#   'Le Figaro tag ID': ['donald-trump'],
#   'MutualArt artist ID': ['88540C56F8DD73BE'],
#   'Apple Music artist ID (U.S. version)': ['501999712'],
#   'Know Your Meme ID': ['12424'],
#   'Comic Vine ID': ['4005-17028'],
#   'Internet Wrestling Database ID': ['donald-trump-9515'],
#   'Radio Radicale person ID': ['213198'],
#   'Rate Your Music artist ID': ['donald-trump'],
#   'MobyGames person ID': ['267590'],
#   'TV Tropes ID': ['UsefulNotes/DonaldTrump'],
#   'writing language': ['English'],
#   'Store norske leksikon ID': ['Donald_Trump'],
#   'Douban movie celebrity ID': ['1018145'],
#   'DR topic ID': ['donald-trump-politiker'],
#   'The Top Tens ID': ['587'],
#   'National Library of Korea ID': ['KAC199627898'],
#   'eye color': ['blue'],
#   'LittleSis people ID': ['15108'],
#   'Daum Encyclopedia ID': ['33XXXXX34701'],
#   'CANTIC ID (former scheme)': ['a19573753'],
#   'Larousse ID': ['personnage/Donald_John_Trump/187816',
#    'images/Donald_Trump/1316060'],
#   'CageMatch worker ID': ['8019'],
#   'Roglo person ID': ['p=donald;n=trump;oc=1'],
#   'The First Amendment Encyclopedia ID': ['1530'],
#   'Lebanese National Library ID': ['33831'],
#   'DBC author ID': ['87097969958575'],
#   'ELNET ID': ['a11394912', 'a11394924'],
#   'National Library of Russia ID': ['770176051'],
#   'RERO ID (obsolete)': ['02-A011627556'],
#   'National Library of Brazil ID': ['000332418'],
#   'PLWABN ID': ['9810632409005606'],
#   'EGAXA ID': ['Balis72483214'],
#   'BNMM authority ID': ['000053733'],
#   'Canadiana Authorities ID (former scheme)': ['1030L0724'],
#   'NicoNicoPedia ID': ['ドナルド・トランプ'],
#   'Project Gutenberg author ID': ['49704'],
#   'CineMagia person ID': ['43230'],
#   'Hrvatska enciklopedija ID': ['70259'],
#   'Brockhaus Enzyklopädie online ID': ['trump-donald-john'],
#   'Artnet artist ID': ['donald-trump'],
#   'University of Barcelona authority ID (former scheme)': ['a1400722'],
#   'WhoSampled artist ID': ['Donald-Trump'],
#   'The Numbers person ID': ['556450401'],
#   'Fandango person ID': ['680884'],
#   'Deutsche Biographie (GND) ID': ['118834312'],
#   'Sejm-Wielki.pl profile ID': ['sw.668528'],
#   'LibraryThing author ID': ['trumpdonald'],
#   'Metacritic ID': ['person/donald-trump'],
#   'Giant Bomb ID': ['3040-78059'],
#   'BabelNet ID': ['03259764n'],
#   'Wolfram Language entity code': ['Entity["Person", "DonaldTrump::6vv3q"]'],
#   'AnimeClick author ID': ['60708'],
#   'Relationship Science person ID': ['donald-john-trump-sr-24460087'],
#   'RationalWiki ID': ['Donald_Trump'],
#   'Trading Card Database person ID': ['97845'],
#   'TV Guide person ID (former scheme)': ['194141'],
#   'TheTVDB person ID': ['255381'],
#   'National Portrait Gallery (London) person ID': ['mp164915'],
#   'BAnQ authority ID': ['0001170465'],
#   'Canadiana Name Authority ID': ['ncf10658901'],
#   'J9U ID': ['987007278742805171'],
#   'National Library of Lithuania ID': ['LNB:9F6;=pa'],
#   'Slovak National Library (VIAF) ID': ['vtls011600941'],
#   'Basis Wien person ID': ['135035'],
#   'YouTube channel ID': ['UCAql2DyGU2un1Ei2nMYsqOA'],
#   'Yle topic ID': ['18-149907'],
#   'medical condition': ['COVID-19'],
#   'Noovie person ID (archived)': ['226333'],
#   'LongTake person ID': ['donald-trump'],
#   'total revenue': [{'amount': '+73000000',
#     'unit': 'http://www.wikidata.org/entity/Q4917'}],
#   'net profit': [{'amount': '-47400000',
#     'unit': 'http://www.wikidata.org/entity/Q4917'}],
#   'total liabilities': [{'amount': '+421000000',
#     'unit': 'http://www.wikidata.org/entity/Q4917'}],
#   'GeneaStar person ID': ['trumpd'],
#   'BBC News topic ID': ['cp7r8vgl2lgt'],
#   'Letterboxd actor ID': ['donald-trump'],
#   'Fandom article ID': ['muppet:Donald_Trump',
#    'tardis:Donald_Trump',
#    'venturebrothers:Donald_Trump',
#    'marvel:Donald_Trump_(Earth-616)',
#    'marvel:Donald_Trump_(Earth-65)',
#    'disney:Donald_Trump',
#    'prowrestling:Donald_Trump',
#    'supernatural:Donald_Trump',
#    'snl:Donald_Trump',
#    'southpark:Donald_Trump',
#    'homealone:Donald_Trump',
#    'youtube:Donald_J_Trump',
#    'cosplay:Donald_Trump',
#    'simpsons:Donald_Trump'],
#   'Filmweb.pl person ID': ['85413'],
#   'sport': ['golf'],
#   'spouse': ['Ivana Trump', 'Marla Maples', 'Melania Trump'],
#   'hairstyle / hairlength': ['comb over'],
#   'Gab username': ['realDonaldTrump'],
#   'SAPA ID': ['a/0161f56d-4f3e-4e20-9386-db501f3f0d68'],
#   'Proleksis enciklopedija ID': ['146165'],
#   'CONOR.SR ID': ['27475559'],
#   'Snapchat username': ['realdonaldtrump'],
#   'App Store developer ID': ['1467775393'],
#   'Google Play developer slug': ['Donald J Trump For President'],
#   'candidacy in election': ['2016 United States presidential election',
#    '2020 United States presidential election',
#    '2020 Republican Party presidential primaries',
#    '2024 United States presidential election'],
#   'PM20 folder ID': ['pe/017630'],
#   'Internet Speculative Fiction Database author ID': ['151170'],
#   "Who's Who UK ID": ['U245656'],
#   'social media followers': [{'amount': '+88783411', 'unit': '1'},
#    {'amount': '+73359237', 'unit': '1'},
#    {'amount': '+61372835', 'unit': '1'},
#    {'amount': '+51682373', 'unit': '1'},
#    {'amount': '+2750000',
#     'unit': '1',
#     'upperBound': '+2759999',
#     'lowerBound': '+2750000'},
#    {'amount': '+32539172', 'unit': '1'},
#    {'amount': '+87686091', 'unit': '1'},
#    {'amount': '+2710000',
#     'unit': '1',
#     'upperBound': '+2719999',
#     'lowerBound': '+2710000'},
#    {'amount': '+2850000',
#     'unit': '1',
#     'upperBound': '+2859999',
#     'lowerBound': '+2850000'},
#    {'amount': '+3180000',
#     'unit': '1',
#     'upperBound': '+3189999',
#     'lowerBound': '+3180000'}],
#   'Deutsche Synchronkartei actor ID': ['7122'],
#   'member of political party': ['Republican Party',
#    'Reform Party of the United States of America',
#    'Democratic Party',
#    'Republican Party',
#    'independent politician',
#    'Republican Party'],
#   'CNA topic ID': ['donald-trump'],
#   'Visuotinė lietuvių enciklopedija ID': ['donald-trump'],
#   'Ávvir topic ID': ['donald-trump'],
#   'official blog URL': ['https://www.donaldjtrump.com/desk',
#    'https://www.donaldjtrump.com/news'],
#   'Moegirlpedia ID': ['川建国'],
#   'Armeniapedia ID': ['16014'],
#   'NLP ID (old)': ['a0000001184270'],
#   'SNK ID': ['172528'],
#   'Al-Jazeera topic ID': ['tag/donald-trump'],
#   'Media Bias/Fact Check ID': ['donaldjtrump-com'],
#   'base salary': [{'amount': '+400000',
#     'unit': 'http://www.wikidata.org/entity/Q4917'}],
#   'Podchaser creator ID': ['107a4Qug6y'],
#   'Kallías ID': ['PE00560115'],
#   'CANTIC ID': ['981058612637606706'],
#   'Companies House officer ID': ['qcmgW-bhHd3TT1MSNuqHIjWBxLI'],
#   'ABC News topic ID': ['donald-trump'],
#   'Lex ID': ['Donald_Trump'],
#   'Emmys person ID': ['donald-trump'],
#   'National Library of Chile ID': ['000817932'],
#   'UAE University Libraries ID': ['a10002903'],
#   'Der Spiegel topic ID': ['donald_trump'],
#   'Google Arts & Culture entity ID': ['m0cqt90'],
#   'Webb-site person ID': ['2467013'],
#   'Prabook ID': ['208064'],
#   'Change.org decision maker ID': ['donald-trump-18'],
#   'IxTheo authority ID': ['07960904X'],
#   'OpenSanctions ID': ['Q22686'],
#   'C-SPAN person numeric ID': ['20967'],
#   'kino-teatr.ru person ID': ['105628'],
#   'Kinorium person ID': ['654917'],
#   'Smotrim.ru actor profile ID': ['299780'],
#   'Vokrug.tv person ID': ['donald_trump'],
#   'Personality Database profile ID': ['449'],
#   'DeSmog ID': ['donald-trump', 'Donald-Trump'],
#   'Truth Social username': ['realDonaldTrump'],
#   'SBN author ID': ['RAVV282134'],
#   'Twitch channel ID': ['donaldtrump', 'donaldtrump'],
#   'documentation files at': ['SAPA Foundation, Swiss Archive of the Performing Arts'],
#   'Golden ID': ['Donald_Trump-AVMWP3'],
#   'hashtag': ['trump', 'donald_trump', 'donald-trump'],
#   'Famous Birthdays ID': ['people/donald-trump'],
#   'YouTube handle': ['DonaldJTrumpforPresident'],
#   'affiliation string': ['Office of the President of the United States',
#    'President of the United States of America'],
#   'CiNii Research ID': ['1140000791668235520'],
#   'Amazon Music artist ID': ['B07CXWK51B'],
#   'Deezer artist ID': ['14744245'],
#   'Spotify artist ID': ['23U808v5GbnGrEIqalCIXi', '1YElgxZ25jerlMGCQsHaYw'],
#   'KBR person ID': ['14087742'],
#   'Deutsche Synchronkartei person ID': ['DqcKnNufb'],
#   'BookBrainz author ID': ['0baab494-f2f7-401f-b19d-34193958a581'],
#   'University of Barcelona authority ID': ['981058612637606706'],
#   'Ivi person ID': ['donald-tramp'],
#   'subject has role': ['billionaire'],
#   'Great Russian Encyclopedia Online ID (old version)': ['5753873'],
#   'National Library of Ireland ID': ['vtls002641612'],
#   'RILM ID': ['140672'],
#   'Great Russian Encyclopedia portal ID': ['tramp-donal-d-6a37c8'],
#   'BHCL UUID': ['b201c7fa-2ef0-4cf1-a8ce-bcbc974a3c3f'],
#   'subreddit': ['trump',
#    'DonaldTrump',
#    'The_Donald',
#    'TrumpCriticizesTrump',
#    'Trumpvirus'],
#   'WorldCat Entities ID': ['E39PBJdx6kjDbQc3ddXKHrxbh3'],
#   'UOM ID': ['131924'],
#   'Mediapart tag ID': ['trump'],
#   'FranceArchives agent ID': ['221487541'],
#   'Danish National Filmography person ID': ['260632'],
#   'Rumble channel': ['DonaldTrump'],
#   'ethnic group': ['White Americans'],
#   'place of detention': ['Fulton County Jail'],
#   'Biblioteca Nacional de México ID': ['000080058'],
#   'NCL ID': ['002505241'],
#   'U.S. National Archives Identifier': ['286186150'],
#   'ICPSR Personal Names Authority List ID': ['14031'],
#   'Radio France person ID': ['donald-trump'],
#   'Kinobox person ID': ['22260'],
#   'Te Papa agent ID': ['61581'],
#   'WikiKids ID': ['Donald_Trump'],
#   'Our Campaigns candidate ID': ['17830'],
#   'Penguin Random House author ID': ['31480'],
#   'Bloomberg person ID': ['1252249'],
#   'Great American Business Leaders of the 20th Century ID': ['donald_j_trump'],
#   'Gran Enciclopèdia Catalana ID': ['donald-trump'],
#   'Listal ID': ['donald-trump'],
#   'Internet Archive ID': ['trumparchive'],
#   'measured physical quantity': ['hand'],
#   'FilmAffinity person ID': ['867878785'],
#   'Parsifal cluster ID': ['6216'],
#   'museum-digital person ID': ['113553'],
#   'label in sign language': ['Sign-name Trump.jpg',
#    'Donald Trump in SignWriting.svg'],
#   'convicted of': ['falsifying business records'],
#   'TikTok username': ['realdonaldtrump'],
#   'GCD creator ID': ['56087'],
#   'Vikidia article ID': ['en:Donald_Trump',
#    'it:Donald_Trump',
#    'es:Donald_Trump',
#    'eu:Donald_Trump',
#    'fr:Donald_Trump'],
#   'Douban personage ID': ['27223869'],
#   'IAFD actor UUID': ['aecbb808-cfd8-4c80-856a-d31af5605b63'],
#   'Open Library subject ID': ['person:donald_trump_(1946-)'],
#   'Pixiv Encyclopedia ID': ['ドナルド・トランプ'],
#   'statement is subject of': ['false or misleading statements by Donald Trump'],
#   'Political Graveyard politician ID': ['trump-tuck.html#306.67.48']},
#  {'_id': 'Q23530',
#   'occupation': ['jurist', 'politician', 'businessperson'],
#   'position held': ['Prime Minister of Russia',
#    'President of Russia',
#    'Deputy Chairman of the Government of the Russian Federation',
#    'First Deputy Chairman of the Government of the Russian Federation',
#    'Leader of United Russia party',
#    'Kremlin Chief of Staff',
#    'Deputy Chairman of the Security Council of the Russian Federation'],
#   'official residence': ['White House'],
#   'place of birth': ['Saint Petersburg'],
#   'GND ID': ['134036476'],
#   'NDL Authority ID': ['01132243'],
#   'VIAF ID': ['49212824'],
#   'IdRef ID': ['125011954'],
#   'Commons category': ['Dmitry Medvedev'],
#   'ISNI': ['0000000114435126'],
#   'country of citizenship': ['Soviet Union', 'Russia'],
#   'member of political party': ['United Russia',
#    'Communist Party of the Soviet Union'],
#   'field of work': ['politics', 'education'],
#   'Library of Congress authority ID': ['n2008040707'],
#   'educated at': ['Faculty of Law, Saint Petersburg State University'],
#   'date of birth': [{'time': '+1965-09-14T00:00:00Z',
#     'timezone': 0,
#     'before': 0,
#     'after': 0,
#     'precision': 11,
#     'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}],
#   'spouse': ['Svetlana Medvedeva'],
#   'religion or worldview': ['Eastern Orthodoxy'],
#   'instance of': ['human'],
#   'SELIBR ID': ['316537'],
#   'NL CR AUT ID': ['js20061006010'],
#   "topic's main category": ['Category:Dmitry Medvedev'],
#   'image': ['Dmitry Medvedev October 2018 (cropped).jpg'],
#   'Commons gallery': ['Дмитрий Анатольевич Медведев'],
#   'Freebase ID': ['/m/08wdkk'],
#   'signature': ['Signature of Dmitry Medvedev.svg'],
#   'NUKAT ID': ['n2008107899'],
#   'Nationale Thesaurus voor Auteursnamen ID': ['323245285'],
#   'official website': ['http://da-medvedev.ru/'],
#   'described by source': ['Lentapedia (full versions)',
#    'Lentapedia',
#    'Obálky knih'],
#   'Rodovid ID': ['148520'],
#   'Gran Enciclopèdia Catalana ID (former scheme)': ['0422347'],
#   'Munzinger person ID': ['00000024755'],
#   'Parlement.com ID': ['vi40hvdufry4'],
#   'given name': ['Dmitry'],
#   'X username': ['MedvedevRussia', 'MedvedevRussiaE'],
#   'Instagram username': ['damedvedev'],
#   'Facebook username': ['175517041850'],
#   'IMDb ID': ['nm3792617'],
#   'Declarator.org ID': ['542'],
#   'pronunciation audio': ['Ru-DmitryMedvedev.ogg'],
#   'languages spoken, written or signed': ['Russian', 'English'],
#   'NNDB people ID': ['164/000168657'],
#   'award received': ['Order of Glory',
#    'Medal "In Commemoration of the 1000th Anniversary of Kazan"',
#    'Order "For Merit to the Fatherland", 1st class',
#    'Order of the Liberator',
#    'Order "Danaker"',
#    'Medal "10 years of Astana"',
#    'Registered firearms',
#    'Памятная медаль А. М. Горчакова',
#    'Prize of the Government of the Russian Federation in the field of education',
#    'Uatsamonga Order',
#    'maroon beret',
#    'Order of St. Sava',
#    'Order "For Merit to the Fatherland", 2nd class',
#    'Order "For Merit to the Fatherland", 3rd class',
#    'Order of the Star of Palestine',
#    'Grand Cross of the Order of the Sun of Peru\u200e',
#    'Russian Federation Presidential Certificate of Gratitude',
#    'Order of Makarios III',
#    'Order of St. Sergius of Radonezh',
#    'Order of the Sun of Peru'],
#   'FAST ID': ['1915322'],
#   'Encyclopædia Britannica Online ID': ['biography/Dmitry-Medvedev'],
#   'GTAA ID': ['210434'],
#   'Great Russian Encyclopedia Online ID (old version)': ['3183470'],
#   'AlloCiné person ID': ['542672'],
#   'ČSFD person ID': ['222016'],
#   'Photographers’ Identities Catalog ID': ['386184'],
#   'VK ID': ['dm', 'dmlive', 'id53083705'],
#   'New York Times topic ID': ['person/dmitri-medvedev'],
#   'LiveJournal ID': ['blog_medvedev'],
#   'native language': ['Russian'],
#   'C-SPAN person ID': ['dmitrymedvedev'],
#   'Quora topic ID': ['Dmitry-Medvedev'],
#   'residence': ['Saint Petersburg', 'Moscow', 'Novo-Ogaryovo'],
#   'National Library of Latvia ID': ['000126943'],
#   'family name': ['Medvedev'],
#   'Encyclopædia Universalis ID': ['dmitri-medvedev'],
#   'ethnic group': ['Russians'],
#   'employer': ['Saint Petersburg State University'],
#   'height': [{'amount': '+163',
#     'unit': 'http://www.wikidata.org/entity/Q174728'}],
#   'Libris-URI': ['pm148xx73q3rwpl'],
#   'RIA Novosti reference': ['42085789'],
#   'owner of': ['Dorofei'],
#   'CONOR.SI ID': ['179328611'],
#   'Krugosvet article': ['istoriya/MEDVEDEV_DMITRI_ANATOLEVICH.html'],
#   'academic degree': ['PhD in Law'],
#   'name in native language': [{'text': 'Дмитрий Анатольевич Медведев',
#     'language': 'ru'}],
#   'TMDB person ID': ['588040'],
#   'participant in': ['annexation of Crimea by the Russian Federation',
#    'World Economic Forum Annual Meeting 2013'],
#   'sport': ['swimming', 'weightlifting'],
#   'number of children': [{'amount': '+1', 'unit': '1'}],
#   'Brockhaus Enzyklopädie online ID': ['dmitri-medwedjew'],
#   'Store norske leksikon ID': ['Dmitrij_Medvedev'],
#   'Europeana entity': ['agent/base/159104'],
#   'Larousse ID': ['personnage/wd/184054'],
#   'NE.se ID': ['dmitrij-medvedev'],
#   'LittleSis people ID': ['260216'],
#   'Deutsche Biographie (GND) ID': ['134036476'],
#   'Yle topic ID': ['18-130534'],
#   'sex or gender': ['male'],
#   'copyright status as a creator': ['works protected by copyrights'],
#   'candidacy in election': ['2008 Russian presidential election'],
#   'De Agostini ID': ["Medvedev,+Dmitrij+Anatol'evič"],
#   'Alexander Turnbull Library ID': ['258039'],
#   'PLWABN ID': ['9810567278005606'],
#   'BHCL UUID': ['e0c47581-281f-4a74-90a4-f9e94ed6f2e2'],
#   "Who's Who UK ID": ['U247158'],
#   'Kinopoisk person ID': ['5430435'],
#   'SVKKL authority ID': ['0282045-Medvedev-Dmitrij-Anatoljevic-1965'],
#   'Evene ID': ['dmitri-medvedev-36413'],
#   'Visuotinė lietuvių enciklopedija ID': ['dmitrij-medvedev'],
#   'Orthodox Encyclopedia ID': ['2562762'],
#   'NLP ID (old)': ['a0000002411131'],
#   'different from': ['Dmitry Medvedev', 'Dmitry Medvedev'],
#   'Peoples.ru person ID': ['state/king/russia/dmitry_medvedev'],
#   'Biografija.ru ID': ['medvedev-dmitrij-anatolevich'],
#   'Great Encyclopedia of Cyril and Methodius entry ID': ['Медведев Дмитрий Анатольевич'],
#   'Hrvatska enciklopedija ID': ['69504'],
#   'Lex ID': ['Dmitrij_Medvedev'],
#   'Canadiana Name Authority ID': ['ncf11538954'],
#   'National Library of Lithuania ID': ['LNB:BT/D;=BB'],
#   'NACSIS-CAT author ID': ['DA16540685'],
#   'National Library of Russia ID': ['7751496'],
#   'RERO ID (obsolete)': ['02-A017628344'],
#   'Vokrug.tv person ID': ['dmitriy_medvedev'],
#   'Kinorium person ID': ['2191340'],
#   'Online PWN Encyclopedia ID': ['4939612'],
#   'Wikimedia username': ['Dmitry Medvedev for RIAN'],
#   'United Russia member ID': ['6821ab0a-ab56-484e-847c-f0f4504d07fa'],
#   'Telegram username': ['medvedev_telegram'],
#   'IxTheo authority ID': ['559879032'],
#   'OpenSanctions ID': ['Q23530'],
#   'C-SPAN person numeric ID': ['1027246'],
#   'Smotrim.ru actor profile ID': ['251279'],
#   'patronym or matronym': ['Anatolyevich'],
#   'CineMagia person ID': ['351312'],
#   'Golden ID': ['Dmitry_Medvedev-NAYYK4'],
#   'Namuwiki ID': ['드미트리 메드베데프'],
#   'military branch': ['Russian Armed Forces'],
#   'conflict': ['insurgency in the North Caucasus', 'Russo-Georgian War'],
#   'military or police rank': ['colonel'],
#   'CiNii Research ID': ['1140000791804578176'],
#   "topic's main template": ['Template:Dmitry Medvedev'],
#   'child': ['Ilya Medvedev'],
#   'WorldCat Entities ID': ['E39PBJmhRQXY7BRFfcg7P7F9Xd'],
#   'UK Parliament thesaurus ID': ['518362'],
#   'Radio France person ID': ['dmitri-medvedev'],
#   'special rank': ['1st class Active State Councillor of the Russian Federation'],
#   'Kinobox person ID': ['1417461'],
#   'father': ['Anatoly Medvedev'],
#   'mother': ['Yulia Medvedeva'],
#   'WikiKids ID': ['Dmitri_Medvedev'],
#   'Gran Enciclopèdia Catalana ID': ['dmitri-anatoljevic-medvedev'],
#   'government.ru person ID': ['183'],
#   'Oxford Reference overview ID': ['20110803100147425'],
#   'political ideology': ['Russian nationalism'],
#   'Chuvash Encyclopedia person ID': ['3106'],
#   'Vikidia article ID': ['fr:Dmitri_Medvedev'],
#   'video': ['2016-12-31 Поздравление Дмитрия Медведева с Новым годом .webm']},
#  {'_id': 'Q23685',
#   'Perlentaucher ID': ['jimmy-carter'],
#   'given name': ['James', 'Earl'],
#   'award received': ['Nobel Peace Prize',
#    'Presidential Medal of Freedom',
#    'United Nations Prize in the Field of Human Rights',
#    'Félix Houphouët-Boigny Peace Prize',
#    'Indira Gandhi Peace Prize',
#    'Four Freedoms Award – Freedom Medal',
#    'Philadelphia Liberty Medal',
#    'American Peace Award',
#    'Delta Prize for Global Understanding',
#    'International Mediation medal',
#    'Ansel Adams Award',
#    'Catalonia International Prize',
#    'Fulbright Prize',
#    'Hoover Medal',
#    'Albert Schweitzer Prize for Humanitarianism',
#    'Ellis Island Medal of Honor',
#    'National Defense Service Medal',
#    'American Campaign Medal',
#    'World War II Victory Medal',
#    'Order of the Nile',
#    'Order of Vasco Núñez de Balboa',
#    'Order of Manuel Amador Guerrero',
#    'Grand Cross of the Order of the Crown',
#    'Order of the Liberator General San Martín',
#    'Audubon Medal',
#    'Grammy Awards',
#    'Honorary doctor at the Nanjing University',
#    'honorary doctorate from the University of Alberta',
#    'honorary doctorate of Haifa University',
#    'Financial Times Person of the Year',
#    'American Library Association Honorary Membership'],
#   'country of citizenship': ['United States of America'],
#   'place of birth': ['Plains', 'Lillian G. Carter Nursing Center'],
#   'position held': ['President of the United States',
#    'Governor of Georgia',
#    'President-elect of the United States',
#    'member of the Georgia State Senate'],
#   'spouse': ['Rosalynn Carter'],
#   'child': ['Jack Carter',
#    'Amy Carter',
#    'James Earl Carter III',
#    'Jeff Carter'],
#   'Library of Congress authority ID': ['n79021791'],
#   'GND ID': ['118519336'],
#   'ISNI': ['0000000369603101'],
#   'Commons category': ['Jimmy Carter'],
#   'VIAF ID': ['247888433'],
#   'MusicBrainz artist ID': ['74a3d3d7-1292-4f6f-8d64-7092392bbde6'],
#   'date of birth': [{'time': '+1924-10-01T00:00:00Z',
#     'timezone': 0,
#     'before': 0,
#     'after': 0,
#     'precision': 11,
#     'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}],
#   'military branch': ['United States Navy'],
#   'occupation': ['naval officer',
#    'diplomat',
#    'novelist',
#    'politician',
#    'farmer',
#    'autobiographer',
#    'submariner',
#    'statesperson',
#    'environmentalist',
#    'businessperson',
#    'engineer',
#    'peace activist',
#    'human rights activist',
#    'writer',
#    'humanitarian'],
#   'educated at': ['Georgia Southwestern State University',
#    'Georgia Tech',
#    'United States Naval Academy',
#    'Union College'],
#   'member of political party': ['Democratic Party'],
#   'father': ['James Earl Carter Sr.'],
#   'mother': ['Lillian Gordy Carter'],
#   'member of': ['American Academy of Arts and Sciences',
#    'American Legion',
#    'Trilateral Commission'],
#   'instance of': ['human'],
#   "topic's main category": ['Category:Jimmy Carter'],
#   'NDL Authority ID': ['00435428'],
#   'National Library of Israel ID (old)': ['000028858'],
#   'SELIBR ID': ['180317'],
#   'Nationale Thesaurus voor Auteursnamen ID': ['068411669'],
#   'Portuguese National Library author ID': ['31096'],
#   'IdRef ID': ['026769514'],
#   'Libraries Australia ID': ['35026279'],
#   'Union List of Artist Names ID': ['500238210'],
#   'Bibliothèque nationale de France ID': ['11895360f'],
#   'Commons gallery': ['Jimmy Carter'],
#   'Freebase ID': ['/m/042kg'],
#   'CANTIC ID (former scheme)': ['a10060078'],
#   'Munzinger person ID': ['00000014585'],
#   'Open Plaques subject ID': ['9122'],
#   'family name': ['Carter'],
#   'Discogs artist ID': ['1288332'],
#   'signature': ['JimmyCarterSignature commons.png',
#    'Signature of Jimmy Carter in 1980 (cropped).jpg'],
#   'name in native language': [{'text': 'Jimmy Carter', 'language': 'en'}],
#   'languages spoken, written or signed': ['English', 'Spanish'],
#   'native language': ['English'],
#   'number of children': [{'amount': '+4', 'unit': '1'}],
#   'archives at': ['Jimmy Carter Library and Museum'],
#   'birth name': [{'text': 'James Earl Carter Jr.', 'language': 'en'}],
#   'genealogics.org person ID': ['I00382187'],
#   'Find a Grave memorial ID': ['6734'],
#   'Rotten Tomatoes ID': ['celebrity/jimmy_carter'],
#   'handedness': ['right-handedness'],
#   'blood type': ['A'],
#   'IMDb ID': ['nm0141699'],
#   'described by source': ['Armenian Soviet Encyclopedia',
#    'Obálky knih',
#    'Miller Center of Public Affairs'],
#   'National Library of Spain ID': ['XX935964'],
#   'NL CR AUT ID': ['jn20000700287'],
#   'NUKAT ID': ['n99009775'],
#   'FAST ID': ['31823'],
#   'TED speaker ID': ['jimmy_carter'],
#   'NNDB people ID': ['386/000022320'],
#   'AlloCiné person ID': ['198673'],
#   'AllMovie person ID': ['p291274'],
#   'ČSFD person ID': ['97618'],
#   'PORT person ID': ['312681'],
#   'Danish National Filmography person ID': ['182293'],
#   'WikiTree person ID': ['Carter-1086'],
#   'Open Library ID': ['OL57418A'],
#   'NORAF ID': ['14009520', '90080122'],
#   'Guardian topic ID': ['us-news/jimmy-carter'],
# ...
#   'TMDB person ID': ['3266140'],
#   'Trading Card Database person ID': ['356'],
#   'Prabook ID': ['1714520'],
#   'languages spoken, written or signed': ['English'],
#   'J9U ID': ['987007451818105171'],
#   'field of work': ['baseball', 'sport management'],
#   'different from': ['Billy Bean'],
#   'National Library of Brazil ID': ['001130007'],
#   'DBC author ID': ['87097919147487'],
#   'WikiTree person ID': ['Beane-630'],
#   'WorldCat Entities ID': ['E39PBJyGQCkb4hxDhbBWgjDyVC']},
#  {'_id': 'Q26318',
#   'IMDb ID': ['nm2837493'],
#   'sex or gender': ['male'],
#   'occupation': ['television actor', 'socialite', 'model', 'businessperson'],
#   'date of birth': [{'time': '+1987-03-17T00:00:00Z',
#     'timezone': 0,
#     'before': 0,
#     'after': 0,
#     'precision': 11,
#     'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}],
#   'instance of': ['human'],
#   'place of birth': ['Los Angeles'],
#   'Freebase ID': ['/m/043n6dp'],
#   'country of citizenship': ['United States of America'],
#   'given name': ['Robert', 'Arthur'],
#   'mother': ['Kris Jenner'],
#   'father': ['Robert Kardashian'],
#   'X username': ['RobKardashian', 'robkardashian'],
#   'ethnic group': ['Armenian Americans'],
#   'educated at': ['USC Marshall School of Business', 'The Buckley School'],
#   'sibling': ['Kourtney Kardashian', 'Kim Kardashian', 'Khloé Kardashian'],
#   'unmarried partner': ['Blac Chyna',
#    'Adrienne Bailon-Houghton',
#    'Rita Ora',
#    'Kara Monaco',
#    'Lisa Ann'],
#   'Snapchat username': ['robphuckedme'],
#   'field of work': ['model'],
#   'family name': ['Kardashian'],
#   'birth name': [{'text': 'Robert Arthur Kardashian', 'language': 'en'}],
#   'child': ['Dream Kardashian'],
#   'languages spoken, written or signed': ['English'],
#   'residence': ['Hidden Hills', 'Calabasas'],
#   'Library of Congress authority ID': ['n2017001635'],
#   'number of children': [{'amount': '+1', 'unit': '1'}],
#   'ČSFD person ID': ['197154'],
#   'Quora topic ID': ['Rob-Kardashian-TV-personality'],
#   'TMDB person ID': ['1677017'],
#   'VIAF ID': ['3716148574392324430009'],
#   'Rotten Tomatoes ID': ['celebrity/rob_kardashian',
#    'celebrity/robert_kardashian_jr'],
#   'work period (start)': [{'time': '+2007-00-00T00:00:00Z',
#     'timezone': 0,
#     'before': 0,
#     'after': 0,
#     'precision': 9,
#     'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}],
#   'Filmweb.pl person ID': ['2393114'],
#   'Instagram username': ['robkardashianofficial'],
#   'Facebook username': ['RobKardashian'],
#   'family': ['Kardashian-Jenner family'],
#   'TV Guide person ID (former scheme)': ['302049'],
#   'stepparent': ['Caitlyn Jenner', 'Corey Gamble'],
#   'relative': ['Kylie Jenner', 'Kendall Jenner'],
#   'hair color': ['brown hair'],
#   'native language': ['American English'],
#   'social media followers': [{'amount': '+7177195', 'unit': '1'},
#    {'amount': '+7439412', 'unit': '1'},
#    {'amount': '+7469320', 'unit': '1'},
#    {'amount': '+7265183', 'unit': '1'}],
#   'name in native language': [{'text': 'Rob Kardashian', 'language': 'en'}],
#   'notable work': ['Keeping Up with the Kardashians', 'Rob & Chyna'],
#   'Armeniapedia ID': ['13104'],
#   'WikiTree person ID': ['Kardashian-5'],
#   'height': [{'amount': '+185',
#     'unit': 'http://www.wikidata.org/entity/Q174728'}],
#   'Prabook ID': ['1915296'],
#   'Famous Birthdays ID': ['people/rob-kardashian'],
#   'BBC Things ID': ['c70fd583-2f30-4aa4-b25d-7c46840fab5a'],
#   'Rodovid ID': ['620644'],
#   'Kinobox person ID': ['1405122'],
#   'WorldCat Entities ID': ['E39PBJm4QdPGMK4YP6WhK93qQq']},
#  {'_id': 'Q26419',
#   'VIAF ID': ['295395095'],
#   'GND ID': ['1030305935'],
#   'date of birth': [{'time': '+1956-01-06T00:00:00Z',
#     'timezone': 0,
#     'before': 0,
#     'after': 0,
#     'precision': 11,
#     'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}],
#   'position held': ['Archbishop of Canterbury',
#    'dean of Liverpool',
#    'Bishop of Durham',
#    'Member of the Privy Council of the United Kingdom',
#    'member of the House of Lords',
#    'member of the House of Lords'],
#   'instance of': ['human'],
#   'place of birth': ['London'],
#   "audio recording of the subject's spoken voice": ['Justin Welby -Today - 26 July 2013.flac'],
#   'Freebase ID': ['/m/03nqpg8'],
#   'image': ['Official portrait of The Lord Archbishop of Canterbury crop 2.jpg'],
#   'educated at': ['Durham University',
#    'Eton College',
#    'Trinity College',
#    'University of Cambridge',
#    'Cranmer Hall, Durham',
#    "St John's College"],
#   'occupation': ['politician',
#    'Anglican priest',
#    'businessperson',
#    'merchant',
#    'theologian',
#    'Christian minister',
#    'archbishop'],
#   'country of citizenship': ['United Kingdom'],
#   'religion or worldview': ['Anglicanism'],
#   'Library of Congress authority ID': ['no2013076593'],
#   'given name': ['Justin'],
#   'Munzinger person ID': ['00000029355'],
#   'Commons category': ['Justin Welby'],
#   'father': ['Anthony Montague Browne', 'Gavin Bramhall Welby'],
#   'genealogics.org person ID': ['I00618055'],
#   'WikiTree person ID': ['Welby-63'],
#   'Quora topic ID': ['Justin-Welby'],
#   'residence': ['Lambeth Palace'],
#   'Encyclopædia Britannica Online ID': ['biography/Justin-Welby'],
#   'ISNI': ['0000000399871203'],
#   'Gran Enciclopèdia Catalana ID (former scheme)': ['21588442'],
#   'Nationale Thesaurus voor Auteursnamen ID': ['096186038'],
#   'family name': ['Welby'],
#   'significant event': ['diaconal ordination',
#    'priestly ordination in the Roman rite',
#    'consecration'],
#   'GTAA ID': ['233735'],
#   'Bibliothèque nationale de France ID': ['16182578m'],
#   'sex or gender': ['male'],
#   'UK Parliament ID': ['HrkWy7lD'],
#   'NL CR AUT ID': ['jo2018998604'],
#   'MusicBrainz artist ID': ['e8aff024-5b50-4515-8ec6-5a56ccdded58'],
#   'member of': ['Travellers Club'],
#   'diocese': ['Diocese of Canterbury'],
#   'coat of arms image': ['Coat of arms of Justin Welby, 105th Archbishop of Canterbury.svg'],
#   'The Peerage person ID': ['p8009.htm#i80090'],
#   'child': ['Johanna Welby',
#    'Timothy Welby',
#    'Katharine Welby',
#    'Peter Welby',
#    'Eleanor Welby',
#    'Hannah Welby'],
#   'mother': ['Jane Gillian Portal'],
#   'FAST ID': ['1961302'],
#   'spouse': ['Caroline Eaton'],
#   'on focus list of Wikimedia project': ['TP updated between September 2019 and August 2020'],
#   'award received': ['honorary doctor of the Catholic University of Paris',
#    'Knight Grand Cross of the Royal Victorian Order'],
#   'Companies House officer ID': ['pWgl5FHjw08byPEtUDollWda2eM',
#    'Ds2_xvNCUy8Qhsev4TvpdTuKtnY',
#    '1LwAv0uRfaplig-7Y_p27PZa_-Y',
#    'B09y0MN25eLqXBjMyCCs3LBiqBc',
#    'jT748sRZYuMlLQERzHyq8K3vlUM'],
#   'writing language': ['British English'],
#   'native language': ['British English'],
#   'languages spoken, written or signed': ['English'],
#   'Biblioteca di Santa Sabina ID': ['10735'],
#   'Podchaser creator ID': ['107aRsDXEq'],
#   'Lex ID': ['Justin_Welby'],
#   'parliament.uk member ID': ['4252'],
#   'IxTheo authority ID': ['735014388'],
#   'NSK ID': ['000762864'],
#   'NUKAT ID': ['n2022141250'],
#   'PLWABN ID': ['9812564184105606'],
#   'Portuguese National Library author ID': ['1792652'],
#   'RERO ID (obsolete)': ['02-A027123303'],
#   'IdRef ID': ['193901668'],
#   'field of work': ['Church of England'],
#   'participant in': ['World Economic Forum Annual Meeting 2016',
#    'World Economic Forum Annual Meeting 2017'],
#   'affiliation string': ['Lambeth Palace'],
#   'OpenSanctions ID': ['Q26419'],
#   'signature': ['Justin Welby Signature.svg'],
#   'BBC Things ID': ['406d91ac-f182-42fa-9afa-d22ccf4c9b73'],
#   'BBC News topic ID': ['cx6m9k26q88t'],
#   "Who's Who UK ID": ['U246114'],
#   'TheyWorkForYou ID': ['25177'],
#   'name in native language': [{'text': 'Justin Welby', 'language': 'en'}],
#   'Gran Enciclopèdia Catalana ID': ['justin-welby'],
#   'Parsifal cluster ID': ['644886'],
#   'WorldCat Entities ID': ['E39PBJgRMCH9KdYgxRxKQhGbVC']},
#  {'_id': 'Q27718',
#   'occupation': ['economist', 'businessperson', 'philosopher'],
#   'country of citizenship': ['United States of America'],
#   'VIAF ID': ['110030376'],
#   'ISNI': ['0000000110824300'],
#   'Commons category': ['Walter Block'],
#   'date of birth': [{'time': '+1941-08-21T00:00:00Z',
#     'timezone': 0,
#     'before': 0,
#     'after': 0,
#     'precision': 11,
#     'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}],
#   'instance of': ['human'],
#   'image': ['Walter block-teaching.jpg', 'Walter Block (34807969945).jpg'],
#   'Freebase ID': ['/m/01hfxf'],
#   'given name': ['Walter'],
#   'Nationale Thesaurus voor Auteursnamen ID': ['071230416'],
#   'Library of Congress authority ID': ['n81027879'],
#   'Commons gallery': ['Walter Block'],
#   'place of birth': ['Brooklyn'],
#   'FAST ID': ['1447783'],
#   'ORCID iD': ['0000-0003-2215-4791'],
#   'NLA Trove people ID': ['1300938'],
#   'religion or worldview': ['atheism'],
#   'National Library of Israel ID (old)': ['000435189'],
#   'IMDb ID': ['nm8159484'],
#   'Goodreads author ID': ['98318'],
#   'Open Library ID': ['OL1024475A'],
#   'doctoral advisor': ['Gary Becker'],
#   'Quora topic ID': ['Walter-Block-2'],
#   'educated at': ['Columbia University',
#    'Brooklyn College',
#    'James Madison High School'],
#   'GND ID': ['131344242'],
#   'SHARE Catalogue author ID': ['19813'],
#   'official website': ['http://www.walterblock.com'],
#   'family name': ['Block'],
#   'BNB person ID': ['BlockWalter1941-'],
#   "topic's main category": ['Category:Walter Block'],
#   'IdRef ID': ['030641152'],
#   'Bibliothèque nationale de France ID': ['122016805'],
#   'sex or gender': ['male'],
#   'NL CR AUT ID': ['vse2008438031'],
#   'Pontificia Università della Santa Croce ID': ['9021'],
#   'NUKAT ID': ['n2010117873'],
#   'described by source': ['Obálky knih'],
#   'National Library of Korea ID': ['KAC200701788'],
#   'Babelio author ID': ['119475'],
#   'languages spoken, written or signed': ['English'],
#   'movement': ['Austrian school'],
#   'residence': ['United States of America'],
#   'J9U ID': ['987007273786005171'],
#   'Prabook ID': ['723903'],
#   'IxTheo authority ID': ['507960807'],
#   'Parsifal cluster ID': ['249170'],
#   'WorldCat Entities ID': ['E39PBJr3rqVppXtHdYfjV7hPwC']},
#  {'_id': 'Q28559',
#   'sex or gender': ['male'],
#   'occupation': ['racing automobile driver', 'businessperson', 'engineer'],
#   'award received': ['Knight of the Legion of Honour'],
#   'VIAF ID': ['13138816'],
#   'GND ID': ['120461072'],
#   'ISNI': ['000000002231516X'],
#   'place of birth': ['Culoz'],
#   'place of death': ['16th arrondissement of Paris'],
#   'country of citizenship': ['France'],
#   'instance of': ['human'],
#   'date of birth': [{'time': '+1858-10-04T00:00:00Z',
#     'timezone': 0,
#     'before': 0,
#     'after': 0,
#     'precision': 11,
#     'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}],
#   'date of death': [{'time': '+1907-02-11T00:00:00Z',
#     'timezone': 0,
#     'before': 0,
#     'after': 0,
#     'precision': 11,
#     'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}],
#   'IdRef ID': ['035152400'],
#   'Library of Congress authority ID': ['n00015859'],
#   'given name': ['Léon'],
#   'image': ['Leon Serpollet.jpg'],
#   'name in native language': [{'text': 'Léon Serpollet', 'language': 'fr'}],
#   'Commons category': ['Léon Serpollet'],
#   'Bibliothèque nationale de France ID': ['13170614j'],
#   'languages spoken, written or signed': ['French'],
#   'FAST ID': ['455923'],
#   'sport': ['auto racing'],
#   'Freebase ID': ['/m/0wbmy7j'],
#   'De Agostini ID': ['Serpollet,+Léon'],
#   'birth name': [{'text': 'Léon Emmanuel Serpollet', 'language': 'fr'}],
#   'Digital Mechanism and Gear Library ID': ['24635004'],
#   'Online PWN Encyclopedia ID': ['3974180'],
#   'Prabook ID': ['2252576'],
#   'Léonore ID': ['LH//2505/39'],
#   'Léonore Web ID': ['344156'],
#   'FranceArchives agent ID': ['19504790'],
#   'WikiTree person ID': ['Serpollet-1'],
#   'WorldCat Entities ID': ['E39PBJqw7t7fVBXDcRMQWKM773']},
#  {'_id': 'Q29279',
#   'sex or gender': ['male'],
#   'VIAF ID': ['48624738'],
#   'Library of Congress authority ID': ['n2004104644'],
#   'IdRef ID': ['153649623'],
#   'occupation': ['entrepreneur', 'businessperson', 'philanthropist'],
#   'instance of': ['human'],
#   'place of birth': ['Busdongo de Arbas'],
#   'date of birth': [{'time': '+1936-03-28T00:00:00Z',
#     'timezone': 0,
#     'before': 0,
#     'after': 0,
#     'precision': 11,
#     'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}],
#   'Freebase ID': ['/m/05qvbg'],
#   'country of citizenship': ['Spain'],
#   'signature': ['Amancio Ortega Gaona signature.png'],
#   'official website': ['http://www.faortega.org/'],
#   'given name': ['Amancio'],
#   'child': ['Sandra Ortega Mera', 'Marcos Ortega Mera', 'Marta Ortega'],
#   'spouse': ['Rosalía Mera', 'Flora Pérez'],
#   'FAST ID': ['1593290'],
#   'award received': ['Castelao Medal',
#    'Grand Cross of the Order of Civil Merit',
#    'Gold Medal of Work Merit'],
#   'languages spoken, written or signed': ['Spanish', 'Galician'],
#   'family name': ['Ortega'],
#   'net worth': [{'amount': '+77000000000',
#     'unit': 'http://www.wikidata.org/entity/Q4917'}],
#   'residence': ['A Coruña'],
#   'Commons category': ['Amancio Ortega'],
#   'Gran Enciclopèdia Catalana ID (former scheme)': ['0282282'],
#   'Quora topic ID': ['Amancio-Ortega'],
#   'Encyclopædia Britannica Online ID': ['biography/Amancio-Ortega'],
#   'BoF person ID': ['amancio-ortega-gaona'],
#   'second family name in Spanish name': ['Gaona'],
#   'National Library of Spain ID': ['XX1672366'],
#   'ISNI': ['000000004928181X'],
#   'name in kana': ['アマンシオ・オルテガ'],
#   'owner of': ['Zara', 'Inditex'],
#   'Munzinger person ID': ['00000029369'],
#   'Treccani ID': ['amancio-ortega-gaona'],
#   'PLWABN ID': ['9810569247405606'],
#   'CANTIC ID (former scheme)': ['a19429009'],
#   'National Library of Israel ID (old)': ['004250035'],
#   'NE.se ID': ['amancio-ortega'],
#   'LittleSis people ID': ['76378'],
#   'birth name': [{'text': 'Amancio Ortega Gaona', 'language': 'es'}],
#   'GND ID': ['121358857X'],
#   'Geni.com profile ID': ['6000000041197203469'],
#   'Google News topics ID': ['CAAqJggKIiBDQkFTRWdvSkwyMHZNRFZ4ZG1KbkVnVmxiaTFIUWlnQVAB'],
#   'name in native language': [{'text': 'Amancio Ortega Gaona',
#     'language': 'es'}],
#   'native language': ['Spanish'],
#   'NLP ID (old)': ['a0000002761877'],
#   'CANTIC ID': ['981058620079706706'],
#   'J9U ID': ['987007334409605171'],
#   'NUKAT ID': ['n2014135073'],
#   'University of Barcelona authority ID (former scheme)': ['a1398608'],
#   'University of Barcelona authority ID': ['981058620079706706'],
#   'Gran Enciclopèdia Catalana ID': ['amancio-ortega-gaona'],
#   'WorldCat Entities ID': ['E39PBJkXqjGKrxQBBVYqcwVQv3']},
#  {'_id': 'Q30865',
#   'sex or gender': ['male'],
#   'Commons category': ['Eike Batista'],
#   'Library of Congress authority ID': ['no2012113950'],
#   'image': ['EIKE BATISTA (crop).jpg'],
#   'occupation': ['businessperson'],
#   'instance of': ['human'],
#   'place of birth': ['Governador Valadares'],
#   'educated at': ['RWTH Aachen University'],
#   'date of birth': [{'time': '+1956-11-03T00:00:00Z',
#     'timezone': 0,
#     'before': 0,
#     'after': 0,
#     'precision': 11,
#     'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}],
#   'Freebase ID': ['/m/04f_knd'],
#   'country of citizenship': ['Brazil', 'Germany'],
#   'given name': ['Eike'],
#   'GND ID': ['1060357313'],
#   'VIAF ID': ['255377309'],
#   'spouse': ['Luma de Oliveira'],
#   'X username': ['eikebatista'],
#   'official website': ['http://www.eikebatista.com.br/'],
#   'Quora topic ID': ['Eike-Batista'],
#   'Encyclopædia Britannica Online ID': ['biography/Eike-Batista'],
#   'family name': ['Batista'],
#   'ISNI': ['0000000377766752'],
#   'convicted of': ['bribery'],
#   'FAST ID': ['1943179'],
#   'Instagram username': ['realeikebatista'],
#   'PLWABN ID': ['9810539253005606'],
#   'social media followers': [{'amount': '+1154718', 'unit': '1'},
#    {'amount': '+1276903', 'unit': '1'},
#    {'amount': '+1113538', 'unit': '1'},
#    {'amount': '+1098850', 'unit': '1'}],
#   'languages spoken, written or signed': ['German'],
#   'NLP ID (old)': ['a0000002766222'],
#   'Munzinger person ID': ['00000028534'],
#   'AdoroCinema person ID': ['706122'],
#   'Prabook ID': ['722483'],
#   'Rodovid ID': ['604067'],
#   'WorldCat Entities ID': ['E39PBJdmkRtbM9RRXg8tchHcT3']}]
